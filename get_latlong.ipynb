# %% [markdown]
# <a href="https://colab.research.google.com/github/VCLF/Coursera_Capstone/blob/master/get_latlong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import pandas as pd
import numpy as np

#!conda install -c conda-forge geopy --yes
import geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %%
url = 'https://thiagorodrigo.com.br/artigo/cep-sao-paulo-lista-de-cep-por-bairro-e-cidade-da-grande-sao-paulo/'
web = pd.read_html(url)
df=web[0]
df['CEP'] = '0'
for i in range(len(df['Faixa de CEP'])):
  text = df.loc[i,'Faixa de CEP']
  text = text.split(' ')
  #print(int(text[0]))
  df.loc[i,'CEP'] = '0' + str((int(text[0]) + int(text[2]))//2)
df.loc[21,'CEP'] = '03540'
df.loc[22,'CEP'] = '03640'
df.loc[25,'CEP'] = '03940'
df.loc[48,'CEP'] = '05740'

# %%
# initialize your variable to None
df['Latitude'] = 0
df['Longitude'] = 0

for i, local in enumerate(df['CEP']):
    zona = df.loc[i,'Zona de São Paulo']
    zona = zona.split(' ')
    if zona[2]=='Zona':
      df.loc[i,'Zona de São Paulo'] = zona[3]
    else:
      df.loc[i,'Zona de São Paulo'] = zona[2]
    bairro = df.loc[i,'Bairros Atendidos']
    bairro = bairro.split('-')
    df.loc[i,'Bairros Atendidos'] = bairro[0]
    location = None
    locator = Nominatim(user_agent= 'myGeocoder')
    string = ''
    string = local + ', Sao Paulo, Brazil'
    print(string)
    while(location is None):
        location = locator.geocode(string)
    
    df.loc[i,'Latitude'] = location.latitude
    df.loc[i,'Longitude'] = location.longitude

df.head()
# Out:
# 01049, Sao Paulo, Brazil
# 01149, Sao Paulo, Brazil
# 01249, Sao Paulo, Brazil
# 01349, Sao Paulo, Brazil
# 01449, Sao Paulo, Brazil
# 01549, Sao Paulo, Brazil
# 02049, Sao Paulo, Brazil
# 02149, Sao Paulo, Brazil
# 02249, Sao Paulo, Brazil
# 02349, Sao Paulo, Brazil
# 02449, Sao Paulo, Brazil
# 02549, Sao Paulo, Brazil
# 02649, Sao Paulo, Brazil
# 02749, Sao Paulo, Brazil
# 02849, Sao Paulo, Brazil
# 02949, Sao Paulo, Brazil
# 03049, Sao Paulo, Brazil
# 03149, Sao Paulo, Brazil
# 03249, Sao Paulo, Brazil
# 03349, Sao Paulo, Brazil
# 03449, Sao Paulo, Brazil
# 03540, Sao Paulo, Brazil
# 03640, Sao Paulo, Brazil
# 03749, Sao Paulo, Brazil
# 03849, Sao Paulo, Brazil
# 03940, Sao Paulo, Brazil
# 08049, Sao Paulo, Brazil
# 08149, Sao Paulo, Brazil
# 08249, Sao Paulo, Brazil
# 08349, Sao Paulo, Brazil
# 08449, Sao Paulo, Brazil
# 04049, Sao Paulo, Brazil
# 04149, Sao Paulo, Brazil
# 04249, Sao Paulo, Brazil
# 04349, Sao Paulo, Brazil
# 04449, Sao Paulo, Brazil
# 04549, Sao Paulo, Brazil
# 04649, Sao Paulo, Brazil
# 04749, Sao Paulo, Brazil
# 04849, Sao Paulo, Brazil
# 04949, Sao Paulo, Brazil
# 05049, Sao Paulo, Brazil
# 05149, Sao Paulo, Brazil
# 05249, Sao Paulo, Brazil
# 05349, Sao Paulo, Brazil
# 05449, Sao Paulo, Brazil
# 05549, Sao Paulo, Brazil
# 05649, Sao Paulo, Brazil
# 05740, Sao Paulo, Brazil
# 05849, Sao Paulo, Brazil
#   Zona de São Paulo Bairros Atendidos  ...   Latitude  Longitude
# 0            Centro           CENTRO   ...  -8.810072  13.252747
# 1            Centro       BOM RETIRO   ... -29.129886 -51.987989
# 2            Centro     VILA BUARQUE   ... -29.129886 -51.987989
# 3            Centro       CONSOLAÇÃO   ... -21.819488 -48.993295
